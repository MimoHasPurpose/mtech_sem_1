# %% [markdown]
# ## Aim: house price prediction  via linear regression on Houstan house price dataset

# %% [markdown]
# ## Theory
# To predict house price prediction with linear regression on Houstan house price
# - library used: `from sklearn.linear_model import LinearRegression`

# %% [markdown]
# ## Code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
from scipy import stats
# %matplotlib inline
from sklearn.metrics import accuracy_score


import pandas as pd

with open('data/houstan.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

df.to_csv('houstan.csv', encoding='utf-8', index=False)

df2.info()

df2.describe()

df2.columns
df2["price"][0]

df2=pd.read_csv('data/houstan.csv',low_memory=False)

y=df2["price"]

y

y=[s.replace("$","") for s in y]

y;


y=[s.replace(",","") for s in y]

y;

import re

cleaned = []
for s in y:
    # keep digits and dot only
    num = re.sub(r"[^\d.]", "", s)
    if num:  # non-empty
        if "." in num:
            cleaned.append(float(num))
        else:
            cleaned.append(int(num))



cleaned;

X=df2["area"]

X[25943]

X = X.fillna(2000)

X

df2.columns

df2["pgapt"]

df2["area"].head()

df2.head(10)

df2.columns

df.columns

X=df[["NOX","RM"]]



X=df2["beds"]
X=X.fillna(3)

X

## Linear regression

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, cleaned, test_size=0.4)


lm = LinearRegression()
lm.fit(X_train,y_train)

predictions = lm.predict(X_test)


accuracy_score(y_true, y_pred)




type(predictions)

y = np.array(y_test)


plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
plt.show()

## Result

from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %% [markdown]
# ## Learning Outcome
# - train test split
# - metrics for data

# %% [markdown]
# ## References:
#
# - state space tree
# -  optimization search technique
# - https://www.geeksforgeeks.org/artificial-intelligence/state-space-search-in-ai/
#  - aiml book
#
#
# https://data-driven-world.github.io/2023/notes/sm/state-space-search/
# ensure that metrics are approp for linear regressions.
# dont use classification matrix in regression
#
# https://www.kaggle.com/datasets/datadetective08/houston-housing-market-2024
