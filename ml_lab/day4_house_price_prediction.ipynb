# %% [markdown]
# ## Aim: house price prediction  via linear regression on Houstan house price dataset

# %% [markdown]
# ## Theory
# To predict house price prediction with linear regression on Houstan house price
# - library used: `from sklearn.linear_model import LinearRegression`

# %% [markdown]
# ## Code

# %%
import pandas as pd

with open('data/houstan.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

df.to_csv('houstan.csv', encoding='utf-8', index=False)

# %%
df.plot.scatter('rm', 'medv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25948 entries, 0 to 25947
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   zpid                         25948 non-null  int64
#  1   id                           25948 non-null  int64
#  2   rawHomeStatusCd              25948 non-null  object
#  3   marketingStatusSimplifiedCd  25948 non-null  object
#  4   imgSrc                       25948 non-null  object
#  5   hasImage                     25839 non-null  float64
#  6   detailUrl                    25948 non-null  object
#  7   statusType                   25948 non-null  object
#  8   statusText                   25948 non-null  object
#  9   countryCurrency              25948 non-null  object
#  10  price                        25948 non-null  object
#  11  unformattedPrice             25948 non-null  int64
#  12  address                      25948 non-null  object
#  13  addressStreet                25947 non-null  object
#  14  addressCity                  25948 non-null  object
#  15  addressState                 25948 non-null  object
#  16  addressZipcode               25948 non-null  int64
#  17  isUndisclosedAddress         25948 non-null  bool
#  18  beds                         22795 non-null  float64
#  19  baths                        25911 non-null  float64
#  20  area                         22792 non-null  float64
#  21  latLong                      25948 non-null  object
#  22  isZillowOwned                25948 non-null  bool
#  23  variableData                 13831 non-null  object
#  24  hdpData                      25948 non-null  object
#  25  isSaved                      25948 non-null  bool
#  26  isUserClaimingOwner          25948 non-null  bool
#  27  isUserConfirmedClaim         25948 non-null  bool
#  28  pgapt                        25948 non-null  object
#  29  sgapt                        25948 non-null  object
#  30  zestimate                    21521 non-null  float64
#  31  shouldShowZestimateAsPrice   25948 non-null  bool
#  32  has3DModel                   25948 non-null  bool
#  33  hasVideo                     25948 non-null  bool
#  34  isHomeRec                    25948 non-null  bool
#  35  hasAdditionalAttributions    25948 non-null  bool
#  36  isFeaturedListing            25948 non-null  bool
#  37  isShowcaseListing            25948 non-null  bool
#  38  list                         25948 non-null  bool
#  39  relaxed                      25948 non-null  bool
#  40  brokerName                   21792 non-null  object
#  41  carouselPhotos               25859 non-null  object
#  42  hasOpenHouse                 1235 non-null   float64
#  43  openHouseStartDate           1235 non-null   object
#  44  openHouseEndDate             1235 non-null   object
#  45  openHouseDescription         1235 non-null   object
#  46  lotAreaString                3067 non-null   object
#  47  providerListingId            5791 non-null   float64
#  48  builderName                  7887 non-null   object
#  49  streetViewURL                109 non-null    object
#  50  streetViewMetadataURL        109 non-null    object
#  51  isPropertyResultCDP          3400 non-null   float64
#  52  flexFieldText                12117 non-null  object
#  53  flexFieldType                12117 non-null  object
#  54  info3String                  23 non-null     object
#  55  info6String                  13 non-null     object
#  56  info2String                  1 non-null      object
#  57  availabilityDate             9 non-null      object
# dtypes: bool(14), float64(8), int64(4), object(32)
# memory usage: 9.1+ MB

# %%
df2.describe()
# Out:
#                zpid            id  hasImage  unformattedPrice  addressZipcode  \
# count  2.594800e+04  2.594800e+04   25839.0      2.594800e+04    25948.000000
# mean   5.493178e+08  5.493178e+08       1.0      5.407448e+05    77282.955064
# std    7.844849e+08  7.844849e+08       0.0      9.313095e+05      204.842402
# min    2.648851e+07  2.648851e+07       1.0      0.000000e+00    77002.000000
# 25%    2.838423e+07  2.838423e+07       1.0      2.790000e+05    77056.000000
# 50%    1.611551e+08  1.611551e+08       1.0      3.799000e+05    77357.000000
# 75%    3.501968e+08  3.501968e+08       1.0      5.400000e+05    77459.000000
# max    2.144636e+09  2.144636e+09       1.0      6.900000e+07    78552.000000
#
#                beds         baths          area     zestimate  hasOpenHouse  \
# count  22795.000000  25911.000000  22792.000000  2.152100e+04        1235.0
# mean       3.521299      2.639420   2453.831388  4.995881e+05           1.0
# std        0.959302      1.487969   1466.259194  6.258647e+05           0.0
# min        0.000000      0.000000      0.000000  2.780000e+04           1.0
# 25%        3.000000      2.000000   1694.000000  2.865000e+05           1.0
# 50%        4.000000      3.000000   2230.000000  3.764000e+05           1.0
# 75%        4.000000      3.000000   2880.000000  5.236000e+05           1.0
# max       20.000000     36.000000  87120.000000  3.061410e+07           1.0
#
#        providerListingId  isPropertyResultCDP
# count       5.791000e+03               3400.0
# mean        2.747632e+07                  1.0
# std         7.077728e+06                  0.0
# min         3.879000e+03                  1.0
# 25%         2.940337e+07                  1.0
# 50%         2.982014e+07                  1.0
# 75%         3.013117e+07                  1.0
# max         3.048985e+07                  1.0

# %%
df2.columns
df2["price"][0]
# Out:
# '$450,000'

# %%
## import libraries
import pandas as pd
import numpy as np

# %%
df2=pd.read_csv('houstan.csv',low_memory=False)

# %%
y=df2["price"]

# %%
y
# Out:
# 0        $450,000
# 1        $285,000
# 2        $554,000
# 3        $498,000
# 4        $459,000
#            ...
# 25943    $235,000
# 25944    $234,888
# 25945    $315,000
# 25946    $250,000
# 25947    $299,000
# Name: price, Length: 25948, dtype: object

# %%
y=[s.replace("$","") for s in y]

# %%
y;

# %%
y=[s.replace(",","") for s in y]

# %%
y;

# %%
import re

# %%
cleaned = []
for s in y:
    # keep digits and dot only
    num = re.sub(r"[^\d.]", "", s)
    if num:  # non-empty
        if "." in num:
            cleaned.append(float(num))
        else:
            cleaned.append(int(num))

# %%
cleaned;

# %%
X=df2["area"]

# %%
X[25943]
# Out:
# np.float64(nan)

# %%
X = X.fillna(2000)

# %%
X
# Out:
# 0        1943.0
# 1        2638.0
# 2        3804.0
# 3        3042.0
# 4        3420.0
#           ...
# 25943    2000.0
# 25944    2000.0
# 25945    2000.0
# 25946    2000.0
# 25947    2000.0
# Name: area, Length: 25948, dtype: float64

# %%
df2.columns
# Out:
# Index(['zpid', 'id', 'rawHomeStatusCd', 'marketingStatusSimplifiedCd',
#        'imgSrc', 'hasImage', 'detailUrl', 'statusType', 'statusText',
#        'countryCurrency', 'price', 'unformattedPrice', 'address',
#        'addressStreet', 'addressCity', 'addressState', 'addressZipcode',
#        'isUndisclosedAddress', 'beds', 'baths', 'area', 'latLong',
#        'isZillowOwned', 'variableData', 'hdpData', 'isSaved',
#        'isUserClaimingOwner', 'isUserConfirmedClaim', 'pgapt', 'sgapt',
#        'zestimate', 'shouldShowZestimateAsPrice', 'has3DModel', 'hasVideo',
#        'isHomeRec', 'hasAdditionalAttributions', 'isFeaturedListing',
#        'isShowcaseListing', 'list', 'relaxed', 'brokerName', 'carouselPhotos',
#        'hasOpenHouse', 'openHouseStartDate', 'openHouseEndDate',
#        'openHouseDescription', 'lotAreaString', 'providerListingId',
#        'builderName', 'streetViewURL', 'streetViewMetadataURL',
#        'isPropertyResultCDP', 'flexFieldText', 'flexFieldType', 'info3String',
#        'info6String', 'info2String', 'availabilityDate'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# import seaborn as sns
from scipy import stats
# %matplotlib inline

# data_url = "http://lib.stat.cmu.edu/datasets/boston"

# %%
df2["pgapt"]
# Out:
# 0        ForSale
# 1        ForSale
# 2        ForSale
# 3        ForSale
# 4        ForSale
#           ...
# 25943    ForSale
# 25944    ForSale
# 25945    ForSale
# 25946    ForSale
# 25947    ForSale
# Name: pgapt, Length: 25948, dtype: object

# %%
df2["area"].head()
# Out:
# 0    1943.0
# 1    2638.0
# 2    3804.0
# 3    3042.0
# 4    3420.0
# Name: area, dtype: float64

# %%
df2.head(10)
# Out:
#         zpid         id rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0  305340899  305340899         ForSale           For Sale by Agent
# 1  160934721  160934721         ForSale           For Sale by Agent
# 2  121106557  121106557         ForSale           For Sale by Agent
# 3   28549516   28549516         ForSale           For Sale by Agent
# 4  123238565  123238565         ForSale           For Sale by Agent
# 5  112159672  112159672         ForSale           For Sale by Agent
# 6   89641740   89641740         ForSale           For Sale by Agent
# 7  112161921  112161921         ForSale           For Sale by Agent
# 8  123239699  123239699         ForSale           For Sale by Agent
# 9  126258491  126258491         ForSale           For Sale by Agent
#
#                                               imgSrc  hasImage  \
# 0  https://photos.zillowstatic.com/fp/c6c062dff72...       1.0
# 1  https://photos.zillowstatic.com/fp/dca8e79a0d4...       1.0
# 2  https://photos.zillowstatic.com/fp/5d7fc370754...       1.0
# 3  https://photos.zillowstatic.com/fp/f7c3f5735ac...       1.0
# 4  https://photos.zillowstatic.com/fp/274024ea250...       1.0
# 5  https://photos.zillowstatic.com/fp/8c97508b71a...       1.0
# 6  https://photos.zillowstatic.com/fp/2e7529d76ed...       1.0
# 7  https://photos.zillowstatic.com/fp/41eb5647ed1...       1.0
# 8  https://photos.zillowstatic.com/fp/0baeede5448...       1.0
# 9  https://photos.zillowstatic.com/fp/84ed6adf9a4...       1.0
#
#                                            detailUrl statusType  \
# 0  https://www.zillow.com/homedetails/13234-Valle...   FOR_SALE
# 1  https://www.zillow.com/homedetails/12235-Green...   FOR_SALE
# 2  https://www.zillow.com/homedetails/13807-Bend-...   FOR_SALE
# 3  https://www.zillow.com/homedetails/14606-Kings...   FOR_SALE
# 4  https://www.zillow.com/homedetails/14434-Mount...   FOR_SALE
# 5  https://www.zillow.com/homedetails/13514-Navig...   FOR_SALE
# 6  https://www.zillow.com/homedetails/16302-Break...   FOR_SALE
# 7  https://www.zillow.com/homedetails/13606-Elm-S...   FOR_SALE
# 8  https://www.zillow.com/homedetails/13746-Nuben...   FOR_SALE
# 9  https://www.zillow.com/homedetails/14427-Mount...   FOR_SALE
#
#        statusText countryCurrency  ... builderName  streetViewURL  \
# 0  House for sale               $  ...         NaN            NaN
# 1  House for sale               $  ...         NaN            NaN
# 2  House for sale               $  ...         NaN            NaN
# 3  House for sale               $  ...         NaN            NaN
# 4  House for sale               $  ...         NaN            NaN
# 5  House for sale               $  ...         NaN            NaN
# 6  House for sale               $  ...         NaN            NaN
# 7  House for sale               $  ...         NaN            NaN
# 8  House for sale               $  ...         NaN            NaN
# 9  House for sale               $  ...         NaN            NaN
#
#   streetViewMetadataURL isPropertyResultCDP flexFieldText flexFieldType  \
# 0                   NaN                 NaN           NaN           NaN
# 1                   NaN                 NaN           NaN           NaN
# 2                   NaN                 NaN           NaN           NaN
# 3                   NaN                 NaN           NaN           NaN
# 4                   NaN                 NaN           NaN           NaN
# 5                   NaN                 NaN           NaN           NaN
# 6                   NaN                 NaN           NaN           NaN
# 7                   NaN                 NaN           NaN           NaN
# 8                   NaN                 NaN           NaN           NaN
# 9                   NaN                 NaN           NaN           NaN
#
#    info3String  info6String  info2String  availabilityDate
# 0          NaN          NaN          NaN               NaN
# 1          NaN          NaN          NaN               NaN
# 2          NaN          NaN          NaN               NaN
# 3          NaN          NaN          NaN               NaN
# 4          NaN          NaN          NaN               NaN
# 5          NaN          NaN          NaN               NaN
# 6          NaN          NaN          NaN               NaN
# 7          NaN          NaN          NaN               NaN
# 8          NaN          NaN          NaN               NaN
# 9          NaN          NaN          NaN               NaN
#
# [10 rows x 58 columns]

# %%
df2.columns
# Out:
# Index(['zpid', 'id', 'rawHomeStatusCd', 'marketingStatusSimplifiedCd',
#        'imgSrc', 'hasImage', 'detailUrl', 'statusType', 'statusText',
#        'countryCurrency', 'price', 'unformattedPrice', 'address',
#        'addressStreet', 'addressCity', 'addressState', 'addressZipcode',
#        'isUndisclosedAddress', 'beds', 'baths', 'area', 'latLong',
#        'isZillowOwned', 'variableData', 'hdpData', 'isSaved',
#        'isUserClaimingOwner', 'isUserConfirmedClaim', 'pgapt', 'sgapt',
#        'zestimate', 'shouldShowZestimateAsPrice', 'has3DModel', 'hasVideo',
#        'isHomeRec', 'hasAdditionalAttributions', 'isFeaturedListing',
#        'isShowcaseListing', 'list', 'relaxed', 'brokerName', 'carouselPhotos',
#        'hasOpenHouse', 'openHouseStartDate', 'openHouseEndDate',
#        'openHouseDescription', 'lotAreaString', 'providerListingId',
#        'builderName', 'streetViewURL', 'streetViewMetadataURL',
#        'isPropertyResultCDP', 'flexFieldText', 'flexFieldType', 'info3String',
#        'info6String', 'info2String', 'availabilityDate'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['TOWN', 'TRACT', 'LON', 'LAT', 'MEDV', 'CRIM', 'ZN', 'INDUS', 'CHAS',
#        'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO'],
#       dtype='object')

# %%
X=df[["NOX","RM"]]

# %%
X=df2["beds"]
X=X.fillna(3)

# %%
X
# Out:
# array([[4.],
#        [4.],
#        [5.],
#        ...,
#        [3.],
#        [3.],
#        [3.]], shape=(25948, 1))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, cleaned, test_size=0.4)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
type(predictions)
# Out:
# numpy.ndarray

# %%
y = np.array(y_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
plt.show()

# %% [markdown]
# ## Result

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 307418.63187981053
# MSE: 500412588899.57275
# RMSE: 707398.4654348444

# %% [markdown]
# ## Learning Outcome
# - train test split
# - metrics for data

# %% [markdown]
# - state space tree
# -  optimization search technique
# - https://www.geeksforgeeks.org/artificial-intelligence/state-space-search-in-ai/
#  - aiml book
#
#
# https://data-driven-world.github.io/2023/notes/sm/state-space-search/
# ensure that metrics are approp for linear regressions.
# dont use classification matrix in regression
#
# https://www.kaggle.com/datasets/datadetective08/houston-housing-market-2024
